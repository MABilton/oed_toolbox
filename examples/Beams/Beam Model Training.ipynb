# %%
import json
import jax
import jax.numpy as jnp
import surrojax_gp
import oed_toolbox

# %%
def load_beam_data(file_dir):
    with open(file_dir, 'r') as f:
        data = json.load(f)
    try:
        x = jnp.stack([jnp.array(data[key]) for key in ('E', 'y_rot')], axis=-1)
        y = jnp.array(jnp.array(data['end_disp'])).reshape(-1,1)
    except KeyError:
        x = jnp.stack([jnp.array(data[key]) for key in ('E', 'Beam Angle')], axis=-1)
        y = jnp.array(jnp.array(data['End Displacement'])).reshape(-1,1)
    return {'x': x, 'y': y}

def scale_data(data):
    for key, val in data.items():
        data[key] = (val- jnp.min(val ,axis=0))/(jnp.max(val ,axis=0) - jnp.min(val ,axis=0))
    return data

linear_data = scale_data(load_beam_data('linear_beam_train.json'))
nonlinear_data = scale_data(load_beam_data('nonlinear_beam_train.json'))
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
def kernel(x_1, x_2, params):
    lengths = jnp.array([params[f"length_{i}"] for i in range(2)])
    inv_lengths = jnp.diag(lengths**(-1))
    ln_k_d = -0.5*(x_1 - x_2).T @ inv_lengths @ (x_1 - x_2) 
    return params["const"]*jnp.exp(ln_k_d)
constraints = {"length_0": {">": 10**-1, "<": 10**1}, 
               "length_1": {">": 10**-1, "<": 10**1}, 
               "const": {">": 10**-1, "<": 10**2}}
linear_gp = surrojax_gp.create_gp(kernel, linear_data['x'], linear_data['y'], constraints)
nonlinear_gp = surrojax_gp.create_gp(kernel, nonlinear_data['x'], nonlinear_data['y'], constraints)
# Out:
# -93.08633
# -133.60971
# -95.6327
# -156.34497
# -240.05603
# -195.32083
# -245.65036
# -172.73447
# -256.8095
# -261.1317
# -263.31085
# -264.59674
# -265.4391
# -263.36307
# -266.41797
# -266.0668
# -267.96014
# -267.65726
# -264.6313
# -264.3997
# -267.65726
# -267.65726
# -268.13397
# -268.13397
# -268.13397
# -265.8656
# -268.13397
# -268.13397
# -267.3597
# -268.13397
# -268.13397
# -265.55286
# -268.13397
# -268.13397
# -266.26984
# -268.13397
# -267.30255
# -267.0605
# -266.83017
# -268.13397
# -268.13397
# -268.13397
# -268.13397
# -268.13397
# -268.13397
# -268.13397
# -268.13397
# -268.13397
# -268.13397
# -268.13397
# -268.13397
# -268.13397
# -268.13397
# -268.13397
# -268.13397
#       fun: array(-268.13397217)
#  hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.07310563,  5.18304443, -4.95946884])
#   message: 'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 55
#       nit: 11
#      njev: 55
#    status: 0
#   success: True
#         x: array([44.64443157,  0.63340229,  0.70003374])
# -141.74521
# -134.26138
# 897.66437
# -141.81198
# -141.58661
# -141.81198
# -141.8552
# -142.60956
# -145.10141
# -237.15903
# -234.41928
# -255.99796
# -251.72507
# -248.47577
# -258.09805
# -259.81024
# -261.78854
# -255.90924
# -256.66995
# -261.78854
# -259.72174
# -260.85284
# -261.78854
# -261.78854
# -261.78854
# -261.78854
# -261.78854
# -261.78854
# -261.78854
# -261.78854
# -261.78854
# -261.78854
# -261.78854
# -261.78854
# -261.78854
# -261.78854
#       fun: array(-261.7885437)
#  hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ -0.27783656,  32.90299988, -28.32697678])
#   message: 'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 36
#       nit: 6
#      njev: 36
#    status: 0
#   success: True
#         x: array([43.87357312,  1.80068937,  0.35420895])
# 599.30786
# -130.27011
# 141.30649
# 11.836418
# -212.94644
# -165.2619
# -220.34802
# -228.08319
# -230.64142
# -229.4679
# -231.38028
# -229.19522
# -231.18164
# -232.8529
# -230.30933
# -230.84882
# -229.59073
# -231.42905
# -232.8529
# -232.8529
# -232.8529
# -232.8529
# -232.8529
# -232.8529
# -232.8529
# -232.8529
# -232.8529
# -232.8529
# -232.8529
#       fun: array(-232.85290527)
#  hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#       jac: array([  0.1108968 ,   9.33355331, -59.6711731 ])
#   message: 'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 29
#       nit: 6
#      njev: 29
#    status: 0
#   success: True
#         x: array([42.13389155,  0.79613129,  0.1939166 ])
# 676.65436
# -137.82632
# 701.95074
# 49.601585
# -193.52158
# -223.62921
# -137.24362
# -225.1023
# -226.40424
# -234.2692
# -217.32889
# -230.36038
# -233.08716
# -233.08994
# -232.28287
# -231.88947
# -234.2692
# -234.2692
# -234.2692
# -234.2692
# -234.2692
# -234.2692
# -234.2692
# -234.2692
# -234.2692
# -234.2692
# -234.2692
#       fun: array(-234.26919556)
#  hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#       jac: array([  0.23391259, -33.43195343, -25.05742645])
#   message: 'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 27
#       nit: 5
#      njev: 27
#    status: 0
#   success: True
#         x: array([37.1064967 ,  0.43720512,  0.29087525])

# %%
linear_beam = oed_toolbox.models.Model.from_surrojax_gp(linear_gp)
nonlinear_beam = oed_toolbox.models.Model.from_surrojax_gp(nonlinear_gp)

# %%
noise_cov = 0.1*jnp.identity(1)
prior_mean = 0.35*jnp.ones((1,))
prior_cov = 0.2*jnp.identity(1)

# %%
minimizer = oed_toolbox.optim.gradient_descent_for_map()
ape = oed_toolbox.losses.APE.using_laplace_approximation(nonlinear_beam, minimizer, prior_mean, \
                                                   prior_cov, noise_cov) #, use_reparameterisation=True
adam = oed_toolbox.optim.adam_for_oed_loss(lr=1e-2)
d_0 = jnp.array([0.5])
num_samples = 100
rng = 19
adam(ape, d_0, num_samples, rng, verbose=True)
# Out:
# Iteration 1: Loss = [-0.2935892], x = [0.51]
# Iteration 2: Loss = [-0.28550205], x = [0.5194105]
# Iteration 3: Loss = [-0.27736187], x = [0.5269654]
# Iteration 4: Loss = [-0.27142977], x = [0.5313043]
# Iteration 5: Loss = [-0.26718264], x = [0.53218794]
# Iteration 6: Loss = [-0.26655979], x = [0.5307567]
# Iteration 7: Loss = [-0.26745393], x = [0.52776676]
# Iteration 8: Loss = [-0.27070768], x = [0.52403164]
# Iteration 9: Loss = [-0.27378957], x = [0.52025443]
# Iteration 10: Loss = [-0.27695231], x = [0.51696104]
# Iteration 11: Loss = [-0.27966165], x = [0.5146551]
# Iteration 12: Loss = [-0.28156678], x = [0.51355875]
# Iteration 13: Loss = [-0.28197101], x = [0.51372266]
# Iteration 14: Loss = [-0.28241868], x = [0.51486605]
# Iteration 15: Loss = [-0.28174064], x = [0.5167316]
# Iteration 16: Loss = [-0.280432], x = [0.5189811]
# Iteration 17: Loss = [-0.27819752], x = [0.5212678]
# Iteration 18: Loss = [-0.27523239], x = [0.5232789]
# Iteration 19: Loss = [-0.2735789], x = [0.52472943]
# Iteration 20: Loss = [-0.27273205], x = [0.52551824]
# Iteration 21: Loss = [-0.27301611], x = [0.5254608]
# Iteration 22: Loss = [-0.27290159], x = [0.5246427]
# Iteration 23: Loss = [-0.27301115], x = [0.52333647]
# Iteration 24: Loss = [-0.27391732], x = [0.52179986]
# Iteration 25: Loss = [-0.27595358], x = [0.52020323]
# Iteration 26: Loss = [-0.27659604], x = [0.51883405]
# Iteration 27: Loss = [-0.27803546], x = [0.51792014]
# Iteration 28: Loss = [-0.27955777], x = [0.51754]
# Iteration 29: Loss = [-0.27912597], x = [0.51776874]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_15928/623126252.py in <module>
#       6 num_samples = 100
#       7 rng = 19
# ----> 8 adam(ape, d_0, num_samples, rng, verbose=True)
#
# /usr/local/lib/python3.8/dist-packages/oed_toolbox/optim.py in adam(oed_loss, d_0, num_samples, rng, args, kwargs, verbose)
#      66         d = d_0
#      67         while num_iter < max_iter:
# ---> 68             loss, grad = oed_loss(d, *args, num_samples=num_samples, rng=rng, **kwargs)
#      69             m_t = compute_exp_avg(new_val=grad, current_avg=m_tm1, wt=beta_1)
#      70             v_t = compute_exp_avg(new_val=grad**2, current_avg=v_tm1, wt=beta_2)
#
# /usr/local/lib/python3.8/dist-packages/oed_toolbox/losses.py in __call__(self, d, num_samples, samples, rng, return_grad)
#      22         if samples is None:
#      23             samples = {}
# ---> 24         return self._loss_and_grad(d, num_samples, samples, rng, return_grad)
#      25
#      26     @classmethod
#
# /usr/local/lib/python3.8/dist-packages/oed_toolbox/losses.py in ape_and_grad(d, num_samples, samples, rng, return_grad)
#      68             else:
#      69                 y = likelihood.sample(theta, d, num_samples, rng) # shape = (num_samples, y_dim)
# ---> 70             post_vals = posterior.logpdf(theta, y, d, return_dd=return_grad)
#      71             outputs['loss'] = post_vals['logpdf']
#      72             # Need to compute like_grad if we're applying control variates:
#
# /usr/local/lib/python3.8/dist-packages/oed_toolbox/distributions.py in logpdf(self, theta, y, d, return_logpdf, return_dd, return_dy)
#     226     def logpdf(self, theta, y, d, return_logpdf=True, return_dd=False, return_dy=False):
#     227         theta, d, y = utils._preprocess_inputs(theta=theta, d=d, y=y)
# --> 228         outputs = self._func_dict['logpdf_and_grads'](theta, y, d, return_logpdf, return_dd, return_dy)
#     229         return self._reshape_logpdf_outputs(outputs, theta, d)
#     230
#
# /usr/local/lib/python3.8/dist-packages/oed_toolbox/distributions.py in logpdf_and_grads(theta, y, d, return_logpdf, return_dd, return_dy)
#     263             outputs = {}
#     264             if return_logpdf or return_dd:
# --> 265                 t_map = theta_map(theta, y, d)
#     266                 g_map = model.predict(t_map, d)
#     267                 g_dt_map = model.predict_dt(t_map, d)
#
# /usr/local/lib/python3.8/dist-packages/oed_toolbox/distributions.py in theta_map(theta_0, y, d)
#     295
#     296         def theta_map(theta_0, y, d):
# --> 297             return minimizer(map_loss_and_grad, theta_0, args=(y, d))
#     298
#     299         def map_loss_and_grad(theta, y, d):
#
# /usr/local/lib/python3.8/dist-packages/oed_toolbox/optim.py in gradient_descent(map_loss_and_grad, theta_0, args)
#      11         optimisation_successful = False
#      12         while not optimisation_successful:
# ---> 13             theta = attempt_gradient_descent(map_loss_and_grad, theta_0, y, d, lr_i)
#      14             optimisation_successful = np.all(np.isfinite(theta)) & (num_attempts <= max_attempts)
#      15             lr_i *= lr_step
#
# /usr/local/lib/python3.8/dist-packages/oed_toolbox/optim.py in attempt_gradient_descent(map_loss_and_grad, theta_0, y, d, lr_i)
#      26         converged = np.zeros((num_opt_problems,), dtype=bool)
#      27         while not np.all(converged):
# ---> 28             loss, grad = map_loss_and_grad(theta, y, d)
#      29             # Zero-out converged gradients:
#      30             theta = theta - lr_i*np.einsum('a,a...->a...', ~converged, grad)
#
# /usr/local/lib/python3.8/dist-packages/oed_toolbox/distributions.py in map_loss_and_grad(theta, y, d)
#     299         def map_loss_and_grad(theta, y, d):
#     300             y_pred = model.predict(theta, d)
# --> 301             y_del_theta = model.predict_dt(theta, d)
#     302             loss = np.einsum("ai,ij,aj->a", y-y_pred, noise_icov, y-y_pred) + \
#     303                    np.einsum("ai,ij,aj->a", theta-prior_mean, prior_icov, theta-prior_mean)
#
# /usr/local/lib/python3.8/dist-packages/oed_toolbox/models.py in predict_dt(self, theta, d)
#      63         theta, d = utils._preprocess_inputs(theta=theta, d=d)
#      64         num_samples, theta_dim = theta.shape
# ---> 65         return self._model_funcs['model_dt'](theta, d).reshape(num_samples, -1, theta_dim)
#      66
#      67     def predict_dd(self, theta, d):
#
# /usr/local/lib/python3.8/dist-packages/oed_toolbox/models.py in <lambda>(theta, d)
#      37         # Vectorise over sample dimensions and wrap functions:
#      38         def wrap_jax_func(func):
# ---> 39             return lambda theta, d : func(jnp.array(theta, dtype=float), jnp.array(d, dtype=float))
#      40         for key, func in model_funcs.items():
#      41             model_funcs[key] = wrap_jax_func(jax.vmap(func, in_axes=(0,0)))
#
#     [... skipping hidden 1 frame]
#
# ~/.local/lib/python3.8/site-packages/jax/_src/api.py in batched_fun(*args, **kwargs)
#    1450     in_axes_flat = flatten_axes("vmap in_axes", in_tree, (in_axes, 0), kws=True)
#    1451     axis_size = _mapped_axis_size(in_tree, args_flat, in_axes_flat, "vmap", kws=True)
# -> 1452     out_flat = batching.batch(
#    1453         flat_fun, axis_name, axis_size, in_axes_flat,
#    1454         lambda: flatten_axes("vmap out_axes", out_tree(), out_axes)
#
# ~/.local/lib/python3.8/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     164
#     165     try:
# --> 166       ans = self.f(*args, **dict(self.params, **kwargs))
#     167     except:
#     168       # Some transformations yield from inside context managers, so we have to
#
# ~/.local/lib/python3.8/site-packages/jax/_src/api.py in jacfun(*args, **kwargs)
#    1096     tree_map(partial(_check_input_dtype_jacfwd, holomorphic), dyn_args)
#    1097     pushfwd = partial(_jvp, f_partial, dyn_args)
# -> 1098     y, jac = vmap(pushfwd, out_axes=(None, -1))(_std_basis(dyn_args))
#    1099     tree_map(partial(_check_output_dtype_jacfwd, holomorphic), y)
#    1100     example_args = dyn_args[0] if isinstance(argnums, int) else dyn_args
#
#     [... skipping hidden 1 frame]
#
# ~/.local/lib/python3.8/site-packages/jax/_src/api.py in batched_fun(*args, **kwargs)
#    1450     in_axes_flat = flatten_axes("vmap in_axes", in_tree, (in_axes, 0), kws=True)
#    1451     axis_size = _mapped_axis_size(in_tree, args_flat, in_axes_flat, "vmap", kws=True)
# -> 1452     out_flat = batching.batch(
#    1453         flat_fun, axis_name, axis_size, in_axes_flat,
#    1454         lambda: flatten_axes("vmap out_axes", out_tree(), out_axes)
#
# ~/.local/lib/python3.8/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     164
#     165     try:
# --> 166       ans = self.f(*args, **dict(self.params, **kwargs))
#     167     except:
#     168       # Some transformations yield from inside context managers, so we have to
#
# ~/.local/lib/python3.8/site-packages/jax/_src/api.py in _jvp(fun, primals, tangents)
#    2106
#    2107   flat_fun, out_tree = flatten_fun_nokwargs(fun, tree_def)
# -> 2108   out_primals, out_tangents = ad.jvp(flat_fun).call_wrapped(ps_flat, ts_flat)
#    2109   return (tree_unflatten(out_tree(), out_primals),
#    2110           tree_unflatten(out_tree(), out_tangents))
#
# ~/.local/lib/python3.8/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     164
#     165     try:
# --> 166       ans = self.f(*args, **dict(self.params, **kwargs))
#     167     except:
#     168       # Some transformations yield from inside context managers, so we have to
#
# /usr/local/lib/python3.8/dist-packages/oed_toolbox/models.py in wrapped_surrojax_gp(theta, d)
#      20             if x.ndim < 2:
#      21                 x = x[None,:]
# ---> 22             return surrojax_gp.predict(x, return_var=False)['mean']
#      23
#      24         return cls.from_jax_function(wrapped_surrojax_gp)
#
# /usr/local/lib/python3.8/dist-packages/surrojax_gp/gp/gp_class.py in predict(self, x_new, return_var, return_cov, grad)
#      58
#      59         # Perform prediction:
# ---> 60         output_dict = self.predict_functions[grad_key](x_new, return_var, return_cov)
#      61
#      62         return output_dict
#
# /usr/local/lib/python3.8/dist-packages/surrojax_gp/gp/prediction.py in predict_method(self, x_new, return_var, return_cov)
#      28         k_1 = K_1(self.x_train, x_new, self.params)
#      29
# ---> 30         output_dict['mean'] = jnp.einsum("ij...,i->j...", k_1, self.alpha)
#      31
#      32         if return_var:
#
# ~/.local/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py in einsum(out, optimize, precision, _use_xeinsum, *operands)
#    4933
#    4934   contractions = tuple((a, frozenset(b), c) for a, b, c, *_ in contractions)
# -> 4935   return _einsum(operands, contractions, precision)
#    4936
#    4937 # Enable other modules to override einsum_contact_path.
#
#     [... skipping hidden 1 frame]
#
# ~/.local/lib/python3.8/site-packages/jax/_src/api.py in cache_miss(*args, **kwargs)
#     414         fun, static_argnums, static_argnames, donate_argnums, args, kwargs)
#     415     flat_fun, out_tree = flatten_fun(closed_fun, in_tree)
# --> 416     out_flat = xla.xla_call(
#     417         flat_fun, *args_flat,
#     418         device=device, backend=backend, name=flat_fun.__name__,
#
# ~/.local/lib/python3.8/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1630
#    1631   def bind(self, fun, *args, **params):
# -> 1632     return call_bind(self, fun, *args, **params)
#    1633
#    1634   def process(self, trace, fun, tracers, params):
#
# ~/.local/lib/python3.8/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1621       params_tuple, out_axes_transforms)
#    1622   tracers = map(top_trace.full_raise, args)
# -> 1623   outs = primitive.process(top_trace, fun, tracers, params)
#    1624   return map(full_lower, apply_todos(env_trace_todo(), outs))
#    1625
#
# ~/.local/lib/python3.8/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1633
#    1634   def process(self, trace, fun, tracers, params):
# -> 1635     return trace.process_call(self, fun, tracers, params)
#    1636
#    1637   def post_process(self, trace, out_tracers, params):
#
# ~/.local/lib/python3.8/site-packages/jax/interpreters/ad.py in process_call(self, call_primitive, f, tracers, params)
#     321     new_params = (update_params(params, nz_tangents, nz_tangents_out)
#     322                   if update_params else params)
# --> 323     result = call_primitive.bind(f_jvp, *primals, *nonzero_tangents, **new_params)
#     324     primal_out, tangent_out = tree_unflatten(out_tree_def(), result)
#     325     return [JVPTracer(self, p, t) for p, t in zip(primal_out, tangent_out)]
#
# ~/.local/lib/python3.8/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1630
#    1631   def bind(self, fun, *args, **params):
# -> 1632     return call_bind(self, fun, *args, **params)
#    1633
#    1634   def process(self, trace, fun, tracers, params):
#
# ~/.local/lib/python3.8/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1621       params_tuple, out_axes_transforms)
#    1622   tracers = map(top_trace.full_raise, args)
# -> 1623   outs = primitive.process(top_trace, fun, tracers, params)
#    1624   return map(full_lower, apply_todos(env_trace_todo(), outs))
#    1625
#
# ~/.local/lib/python3.8/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1633
#    1634   def process(self, trace, fun, tracers, params):
# -> 1635     return trace.process_call(self, fun, tracers, params)
#    1636
#    1637   def post_process(self, trace, out_tracers, params):
#
# ~/.local/lib/python3.8/site-packages/jax/interpreters/batching.py in process_call(self, call_primitive, f, tracers, params)
#     175     else:
#     176       f, dims_out = batch_subtrace(f, self.main, dims)
# --> 177       vals_out = call_primitive.bind(f, *vals, **params)
#     178       return [BatchTracer(self, v, d) for v, d in zip(vals_out, dims_out())]
#     179
#
# ~/.local/lib/python3.8/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1630
#    1631   def bind(self, fun, *args, **params):
# -> 1632     return call_bind(self, fun, *args, **params)
#    1633
#    1634   def process(self, trace, fun, tracers, params):
#
# ~/.local/lib/python3.8/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1621       params_tuple, out_axes_transforms)
#    1622   tracers = map(top_trace.full_raise, args)
# -> 1623   outs = primitive.process(top_trace, fun, tracers, params)
#    1624   return map(full_lower, apply_todos(env_trace_todo(), outs))
#    1625
#
# ~/.local/lib/python3.8/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1633
#    1634   def process(self, trace, fun, tracers, params):
# -> 1635     return trace.process_call(self, fun, tracers, params)
#    1636
#    1637   def post_process(self, trace, out_tracers, params):
#
# ~/.local/lib/python3.8/site-packages/jax/interpreters/batching.py in process_call(self, call_primitive, f, tracers, params)
#     175     else:
#     176       f, dims_out = batch_subtrace(f, self.main, dims)
# --> 177       vals_out = call_primitive.bind(f, *vals, **params)
#     178       return [BatchTracer(self, v, d) for v, d in zip(vals_out, dims_out())]
#     179
#
# ~/.local/lib/python3.8/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1630
#    1631   def bind(self, fun, *args, **params):
# -> 1632     return call_bind(self, fun, *args, **params)
#    1633
#    1634   def process(self, trace, fun, tracers, params):
#
# ~/.local/lib/python3.8/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1621       params_tuple, out_axes_transforms)
#    1622   tracers = map(top_trace.full_raise, args)
# -> 1623   outs = primitive.process(top_trace, fun, tracers, params)
#    1624   return map(full_lower, apply_todos(env_trace_todo(), outs))
#    1625
#
# ~/.local/lib/python3.8/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1633
#    1634   def process(self, trace, fun, tracers, params):
# -> 1635     return trace.process_call(self, fun, tracers, params)
#    1636
#    1637   def post_process(self, trace, out_tracers, params):
#
# ~/.local/lib/python3.8/site-packages/jax/core.py in process_call(self, primitive, f, tracers, params)
#     625
#     626   def process_call(self, primitive, f, tracers, params):
# --> 627     return primitive.impl(f, *tracers, **params)
#     628   process_map = process_call
#     629
#
# ~/.local/lib/python3.8/site-packages/jax/interpreters/xla.py in _xla_call_impl(***failed resolving arguments***)
#     688                                *unsafe_map(arg_spec, args))
#     689   try:
# --> 690     out = compiled_fun(*args)
#     691   except FloatingPointError:
#     692     assert config.jax_debug_nans or config.jax_debug_infs  # compiled_fun can only raise in this case
#
# ~/.local/lib/python3.8/site-packages/jax/interpreters/xla.py in _execute_compiled(name, compiled, output_buffer_counts, handlers, kept_var_idx, *args)
#    1093                       kept_var_idx, *args):
#    1094   device, = compiled.local_devices()
# -> 1095   input_bufs = list(
#    1096       it.chain.from_iterable(
#    1097           device_put(x, device)
#
# ~/.local/lib/python3.8/site-packages/jax/interpreters/xla.py in <genexpr>(.0)
#    1095   input_bufs = list(
#    1096       it.chain.from_iterable(
# -> 1097           device_put(x, device)
#    1098           for i, x in enumerate(args)
#    1099           if x is not token and i in kept_var_idx))
#
# ~/.local/lib/python3.8/site-packages/jax/interpreters/xla.py in device_put(x, device)
#     297
#     298 def device_put(x, device: Optional[Device] = None) -> Tuple[Any]:
# --> 299   x = canonicalize_dtype(x)
#     300   try:
#     301     return device_put_handlers[type(x)](x, device)
#
# KeyboardInterrupt:

# %%
adam = oed_toolbox.optim.adam_for_oed_loss(lr=1e-2)
d_0 = jnp.array([0.5])
theta_0 = 0.01
num_samples = 100
rng = 19
likelihood = oed_toolbox.distributions.Likelihood.from_model_plus_constant_gaussian_noise(nonlinear_beam, noise_cov)
fisher_info = oed_toolbox.covariances.FisherInformation(likelihood, use_reparameterisation=True)
d_opt = oed_toolbox.losses.D_Optimal(fisher_info)
adam(d_opt, d_0, num_samples, rng, verbose=True, args=(theta_0,))
# Out:
# Iteration 1: Loss = -34.82984924316406, x = [0.51]
# Iteration 2: Loss = -36.699886322021484, x = [0.5200062]
# Iteration 3: Loss = -38.607887268066406, x = [0.5300216]
# Iteration 4: Loss = -40.5485725402832, x = [0.5400486]
# Iteration 5: Loss = -42.49846267700195, x = [0.5500881]
# Iteration 6: Loss = -44.57035827636719, x = [0.56014067]
# Iteration 7: Loss = -46.59259796142578, x = [0.570205]
# Iteration 8: Loss = -48.6211051940918, x = [0.580278]
# Iteration 9: Loss = -50.66379928588867, x = [0.59035516]
# Iteration 10: Loss = -52.697540283203125, x = [0.60042995]
# Iteration 11: Loss = -54.70115661621094, x = [0.61049324]
# Iteration 12: Loss = -56.69696807861328, x = [0.62053376]
# Iteration 13: Loss = -58.57734298706055, x = [0.6305366]
# Iteration 14: Loss = -60.39044952392578, x = [0.6404834]
# Iteration 15: Loss = -62.12944793701172, x = [0.6503518]
# Iteration 16: Loss = -63.73953628540039, x = [0.6601151]
# Iteration 17: Loss = -65.22236633300781, x = [0.6697416]
# Iteration 18: Loss = -66.57312774658203, x = [0.67919385]
# Iteration 19: Loss = -67.72776794433594, x = [0.68842906]
# Iteration 20: Loss = -68.76323699951172, x = [0.6973987]
# Iteration 21: Loss = -69.59044647216797, x = [0.7060483]
# Iteration 22: Loss = -70.2780990600586, x = [0.7143192]
# Iteration 23: Loss = -70.7458724975586, x = [0.7221489]
# Iteration 24: Loss = -71.02561950683594, x = [0.72947377]
# Iteration 25: Loss = -71.1631851196289, x = [0.7362307]
# Iteration 26: Loss = -71.18911743164062, x = [0.742361]
# Iteration 27: Loss = -71.10514068603516, x = [0.74781305]
# Iteration 28: Loss = -71.0146255493164, x = [0.75254536]
# Iteration 29: Loss = -70.7613754272461, x = [0.75653]
# Iteration 30: Loss = -70.61238098144531, x = [0.7597527]
# Iteration 31: Loss = -70.4313735961914, x = [0.7622147]
# Iteration 32: Loss = -70.2378158569336, x = [0.7639328]
# Iteration 33: Loss = -70.10638427734375, x = [0.76493686]
# Iteration 34: Loss = -70.00055694580078, x = [0.765269]
# Iteration 35: Loss = -69.97659301757812, x = [0.76498103]
# Iteration 36: Loss = -70.01532745361328, x = [0.76413274]
# Iteration 37: Loss = -70.06564331054688, x = [0.7627896]
# Iteration 38: Loss = -70.1740951538086, x = [0.76102054]
# Iteration 39: Loss = -70.30846405029297, x = [0.7588968]
# Iteration 40: Loss = -70.49298095703125, x = [0.7564898]
# Iteration 41: Loss = -70.59363555908203, x = [0.7538707]
# Iteration 42: Loss = -70.74394226074219, x = [0.75110847]
# Iteration 43: Loss = -70.82844543457031, x = [0.74826914]
# Iteration 44: Loss = -70.9125747680664, x = [0.74541515]
# Iteration 45: Loss = -71.08500671386719, x = [0.7426042]
# Iteration 46: Loss = -71.12039184570312, x = [0.73988855]
# Iteration 47: Loss = -71.14077758789062, x = [0.7373143]
# Iteration 48: Loss = -71.19647979736328, x = [0.7349209]
# Iteration 49: Loss = -71.20931243896484, x = [0.7327416]
# Iteration 50: Loss = -71.25965881347656, x = [0.7308018]
# Iteration 51: Loss = -71.18841552734375, x = [0.7291211]
# Iteration 52: Loss = -71.16126251220703, x = [0.7277116]
# Iteration 53: Loss = -71.1414794921875, x = [0.7265794]
# Iteration 54: Loss = -71.19786834716797, x = [0.72572386]
# Iteration 55: Loss = -71.11625671386719, x = [0.7251394]
# Iteration 56: Loss = -71.11166381835938, x = [0.72481453]
# Iteration 57: Loss = -71.08258056640625, x = [0.72473425]
# Iteration 58: Loss = -71.09569549560547, x = [0.72487897]
# Iteration 59: Loss = -71.10724639892578, x = [0.7252267]
# Iteration 60: Loss = -71.10910034179688, x = [0.72575307]
# Iteration 61: Loss = -71.09407043457031, x = [0.7264316]
# Iteration 62: Loss = -71.1031265258789, x = [0.7272346]
# Iteration 63: Loss = -71.12113952636719, x = [0.728134]
# Iteration 64: Loss = -71.11748504638672, x = [0.72910196]
# Iteration 65: Loss = -71.16621398925781, x = [0.7301112]
# Iteration 66: Loss = -71.16133117675781, x = [0.73113525]
# Iteration 67: Loss = -71.19633483886719, x = [0.7321493]
# Iteration 68: Loss = -71.1971664428711, x = [0.7331309]
# Iteration 69: Loss = -71.2243423461914, x = [0.73405963]
# Iteration 70: Loss = -71.24540710449219, x = [0.734918]
# Iteration 71: Loss = -71.22726440429688, x = [0.7356912]
# Iteration 72: Loss = -71.18108367919922, x = [0.73636794]
# Iteration 73: Loss = -71.21675872802734, x = [0.73694044]
# Iteration 74: Loss = -71.21247863769531, x = [0.7374036]
# Iteration 75: Loss = -71.18504333496094, x = [0.7377545]
# Iteration 76: Loss = -71.16877746582031, x = [0.7379949]
# Iteration 77: Loss = -71.21900177001953, x = [0.73812777]
# Iteration 78: Loss = -71.16899108886719, x = [0.73815954]
# Iteration 79: Loss = -71.1839828491211, x = [0.738098]
# Iteration 80: Loss = -71.1928939819336, x = [0.7379528]
# Iteration 81: Loss = -71.20435333251953, x = [0.7377354]
# Iteration 82: Loss = -71.18927764892578, x = [0.737458]
# Iteration 83: Loss = -71.19945526123047, x = [0.7371332]
# Iteration 84: Loss = -71.14900207519531, x = [0.736774]
# Iteration 85: Loss = -71.16954040527344, x = [0.73639286]
# Iteration 86: Loss = -71.23151397705078, x = [0.7360021]
# Iteration 87: Loss = -71.19461059570312, x = [0.7356133]
# Iteration 88: Loss = -71.216796875, x = [0.73523647]
# Iteration 89: Loss = -71.21615600585938, x = [0.73488134]
# Iteration 90: Loss = -71.20548248291016, x = [0.7345555]
# Iteration 91: Loss = -71.19013214111328, x = [0.7342647]
# Iteration 92: Loss = -71.21185302734375, x = [0.7340145]
# Iteration 93: Loss = -71.2143783569336, x = [0.73380846]
# Iteration 94: Loss = -71.18307495117188, x = [0.73364794]
# Iteration 95: Loss = -71.22808837890625, x = [0.73353356]
# Iteration 96: Loss = -71.19640350341797, x = [0.7334643]
# Iteration 97: Loss = -71.19358825683594, x = [0.73343825]
# Iteration 98: Loss = -71.18128204345703, x = [0.7334521]
# Iteration 99: Loss = -71.22098541259766, x = [0.73350215]
# Iteration 100: Loss = -71.2083969116211, x = [0.7335836]
# DeviceArray([0.7308018], dtype=float32)

# %%
adam = oed_toolbox.optim.adam_for_oed_loss(lr=1e-2)
d_0 = jnp.array([0.8])
theta_0 = 0.01
num_samples = 10
rng = 19
model = linear_beam
likelihood = oed_toolbox.distributions.Likelihood.from_model_plus_constant_gaussian_noise(model, noise_cov)
fisher_info = oed_toolbox.covariances.FisherInformation(likelihood, use_reparameterisation=True)
pred_cov = oed_toolbox.covariances.PredictiveCovariance(model, fisher_info)
d_opt = oed_toolbox.losses.D_Optimal(pred_cov)
adam(d_opt, d_0, num_samples, rng, verbose=True, args=(theta_0,))
# Out:
# Iteration 1: Loss = -0.21289372444152832, x = [0.8097946]
# Iteration 2: Loss = -0.21289367973804474, x = [0.8188755]
# Iteration 3: Loss = -0.21289370954036713, x = [0.8281681]
# Iteration 4: Loss = -0.21289370954036713, x = [0.8366558]
# Iteration 5: Loss = -0.21289367973804474, x = [0.8438047]
# Iteration 6: Loss = -0.21289369463920593, x = [0.84580326]
# Iteration 7: Loss = -0.21289369463920593, x = [0.84886634]
# Iteration 8: Loss = -0.21289366483688354, x = [0.85156095]
# Iteration 9: Loss = -0.21289366483688354, x = [0.85394835]
# Iteration 10: Loss = -0.21289369463920593, x = [0.85472083]
# Iteration 11: Loss = -0.21289370954036713, x = [0.85541195]
# Iteration 12: Loss = -0.21289367973804474, x = [0.8560323]
# Iteration 13: Loss = -0.21289366483688354, x = [0.85779417]
# Iteration 14: Loss = -0.21289366483688354, x = [0.85814667]
# Iteration 15: Loss = -0.21289369463920593, x = [0.8596114]
# Iteration 16: Loss = -0.21289367973804474, x = [0.8620293]
# Iteration 17: Loss = -0.21289367973804474, x = [0.8642205]
# Iteration 18: Loss = -0.21289367973804474, x = [0.8650394]
# Iteration 19: Loss = -0.21289367973804474, x = [0.864667]
# Iteration 20: Loss = -0.21289366483688354, x = [0.8632559]
# Iteration 21: Loss = -0.21289370954036713, x = [0.86197335]
# Iteration 22: Loss = -0.21289367973804474, x = [0.860807]
# Iteration 23: Loss = -0.21289364993572235, x = [0.85974604]
# Iteration 24: Loss = -0.21289367973804474, x = [0.8587807]
# Iteration 25: Loss = -0.21289369463920593, x = [0.85790217]
# Iteration 26: Loss = -0.21289370954036713, x = [0.8571025]
# Iteration 27: Loss = -0.21289366483688354, x = [0.8575303]
# Iteration 28: Loss = -0.21289367973804474, x = [0.8567843]
# Iteration 29: Loss = -0.21289366483688354, x = [0.8561051]
# Iteration 30: Loss = -0.21289369463920593, x = [0.85548675]
# Iteration 31: Loss = -0.21289367973804474, x = [0.85492384]
# Iteration 32: Loss = -0.21289367973804474, x = [0.8544114]
# Iteration 33: Loss = -0.21289370954036713, x = [0.853945]
# Iteration 34: Loss = -0.21289369463920593, x = [0.8557816]
# Iteration 35: Loss = -0.21289370954036713, x = [0.85631657]
# Iteration 36: Loss = -0.21289367973804474, x = [0.85569525]
# Iteration 37: Loss = -0.21289367973804474, x = [0.85725087]
# Iteration 38: Loss = -0.21289370954036713, x = [0.8596845]
# Iteration 39: Loss = -0.21289369463920593, x = [0.8608318]
# Iteration 40: Loss = -0.21289366483688354, x = [0.85983735]
# Iteration 41: Loss = -0.21289369463920593, x = [0.8563075]
# Iteration 42: Loss = -0.21289370954036713, x = [0.8549789]
# Iteration 43: Loss = -0.21289369463920593, x = [0.85377073]
# Iteration 44: Loss = -0.21289370954036713, x = [0.85267216]
# Iteration 45: Loss = -0.21289364993572235, x = [0.8507854]
# Iteration 46: Loss = -0.21289370954036713, x = [0.85087967]
# Iteration 47: Loss = -0.21289370954036713, x = [0.8518401]
# Iteration 48: Loss = -0.21289364993572235, x = [0.851829]
# Iteration 49: Loss = -0.21289364993572235, x = [0.8501061]
# Iteration 50: Loss = -0.21289367973804474, x = [0.84854084]
# Iteration 51: Loss = -0.21289369463920593, x = [0.847119]
# Iteration 52: Loss = -0.21289364993572235, x = [0.8449637]
# Iteration 53: Loss = -0.21289367973804474, x = [0.8430065]
# Iteration 54: Loss = -0.21289369463920593, x = [0.8412293]
# Iteration 55: Loss = -0.21289367973804474, x = [0.83873767]
# Iteration 56: Loss = -0.21289370954036713, x = [0.83560145]
# Iteration 57: Loss = -0.21289370954036713, x = [0.83366835]
# Iteration 58: Loss = -0.21289370954036713, x = [0.83371234]
# Iteration 59: Loss = -0.21289364993572235, x = [0.8333122]
# Iteration 60: Loss = -0.21289369463920593, x = [0.83294916]
# Iteration 61: Loss = -0.21289370954036713, x = [0.83394563]
# Iteration 62: Loss = -0.21289369463920593, x = [0.83614755]
# Iteration 63: Loss = -0.21289367973804474, x = [0.83814484]
# Iteration 64: Loss = -0.21289367973804474, x = [0.84082663]
# Iteration 65: Loss = -0.21289370954036713, x = [0.8432586]
# Iteration 66: Loss = -0.21289367973804474, x = [0.8454639]
# Iteration 67: Loss = -0.21289366483688354, x = [0.8474633]
# Iteration 68: Loss = -0.21289369463920593, x = [0.85016716]
# Iteration 69: Loss = -0.21289366483688354, x = [0.85169894]
# Iteration 70: Loss = -0.21289366483688354, x = [0.8521742]
# Iteration 71: Loss = -0.21289367973804474, x = [0.852605]
# Iteration 72: Loss = -0.21289367973804474, x = [0.8529954]
# Iteration 73: Loss = -0.21289367973804474, x = [0.8542645]
# Iteration 74: Loss = -0.21289366483688354, x = [0.85358363]
# Iteration 75: Loss = -0.21289366483688354, x = [0.85206807]
# Iteration 76: Loss = -0.21289366483688354, x = [0.850695]
# Iteration 77: Loss = -0.21289367973804474, x = [0.84945124]
# Iteration 78: Loss = -0.21289369463920593, x = [0.84832466]
# Iteration 79: Loss = -0.21289364993572235, x = [0.84638965]
# Iteration 80: Loss = -0.21289367973804474, x = [0.84648764]
# Iteration 81: Loss = -0.21289366483688354, x = [0.8456697]
# Iteration 82: Loss = -0.21289369463920593, x = [0.844929]
# Iteration 83: Loss = -0.21289369463920593, x = [0.84517425]
# Iteration 84: Loss = -0.21289366483688354, x = [0.846308]
# Iteration 85: Loss = -0.21289367973804474, x = [0.8482423]
# Iteration 86: Loss = -0.21289367973804474, x = [0.85089797]
# Iteration 87: Loss = -0.21289372444152832, x = [0.85505366]
# Iteration 88: Loss = -0.21289370954036713, x = [0.8605171]
# Iteration 89: Loss = -0.21289369463920593, x = [0.8654622]
# Iteration 90: Loss = -0.21289369463920593, x = [0.87080973]
# Iteration 91: Loss = -0.21289367973804474, x = [0.87564933]
# Iteration 92: Loss = -0.21289367973804474, x = [0.88002896]
# Iteration 93: Loss = -0.21289372444152832, x = [0.8848772]
# Iteration 94: Loss = -0.21289370954036713, x = [0.8901479]
# Iteration 95: Loss = -0.21289369463920593, x = [0.8939893]
# Iteration 96: Loss = -0.21289367973804474, x = [0.89654297]
# Iteration 97: Loss = -0.21289369463920593, x = [0.8970235]
# Iteration 98: Loss = -0.21289366483688354, x = [0.8974582]
# Iteration 99: Loss = -0.21289367973804474, x = [0.89695054]
# Iteration 100: Loss = -0.21289366483688354, x = [0.8939]
# DeviceArray([0.8097946], dtype=float32)
